# %%
# ██████╗░███████╗░██████╗░██╗███╗░░██╗  ███████╗██╗░░██╗███████╗██████╗░░█████╗░██╗░██████╗███████╗
# ██╔══██╗██╔════╝██╔════╝░██║████╗░██║  ██╔════╝╚██╗██╔╝██╔════╝██╔══██╗██╔══██╗██║██╔════╝██╔════╝
# ██████╦╝█████╗░░██║░░██╗░██║██╔██╗██║  █████╗░░░╚███╔╝░█████╗░░██████╔╝██║░░╚═╝██║╚█████╗░█████╗░░
# ██╔══██╗██╔══╝░░██║░░╚██╗██║██║╚████║  ██╔══╝░░░██╔██╗░██╔══╝░░██╔══██╗██║░░██╗██║░╚═══██╗██╔══╝░░
# ██████╦╝███████╗╚██████╔╝██║██║░╚███║  ███████╗██╔╝╚██╗███████╗██║░░██║╚█████╔╝██║██████╔╝███████╗
# ╚═════╝░╚══════╝░╚═════╝░╚═╝╚═╝░░╚══╝  ╚══════╝╚═╝░░╚═╝╚══════╝╚═╝░░╚═╝░╚════╝░╚═╝╚═════╝░╚══════╝

# %% [markdown]
# ## Problem 1.

# %%
from function_exercises import is_vowel

# %%
import function_exercises as fx

# %%
fx.get_letter_grade(86)
# Out:
# 'B'

# %% [markdown]
# ## Problem 2.

# %%
import itertools as it

# %%
print('There are',len(list(it.product([1,2,3],'abc'))), 'possible different combinations of 1,2,3 with ABC')
# Out:
# There are 9 possible different combinations of 1,2,3 with ABC

# %%
print('There are',len(list(it.combinations('abcd',2))), 'possible combinations of 2 letters from ABCD')
# Out:
# There are 6 possible combinations of 2 letters from ABCD

# %%
print('There are',len(list(it.permutations('abcd',2))), 'different permutations of ABCD')
# Out:
# There are 12 different permutations of ABCD

# %% [markdown]
# ## Problem 3.

# %%
import json
#with open('profiles.json') as prof:
#    data = prof.read()

# opening profiles json file
profiles = open('profiles.json')

#returns json object as a dictionary
data = json.load(profiles)

#a differently parsed version of the profiles dictionary
pretty_data = json.dumps(data, indent=4, sort_keys=True)

#json.load(open('profiles.json'))
#print(data)

# %%
len(data)
# Out:
# 19

# %% [markdown]
# ### Active users

# %%
count = 0

for i in data:
    if i['isActive'] == True:
        count +=1
print(count)
# Out:
# 9

# %% [markdown]
# ### Balance

# %%
i['balance'].strip('$').replace(',','')
# Out:
# '2227.79'

# %% [markdown]
# ### Grand Total

# %%
grand_total = 0

for i in data:
    user_balance = float(i['balance'].strip('$').replace(',',''))
    grand_total += user_balance
print(grand_total)
# Out:
# 52667.02

# %% [markdown]
# ### Average cash of all users

# %%
round(grand_total / len(data), 2)
# Out:
# 2771.95

# %% [markdown]
# ### Average Balances

# %%
balance_ls = []

for i in data:
    print(i

fruits = []

# %%
for i in data:
    if i['balance'].strip('$').replace(',','') == min(balance_ls):
        print(f'User {i["name"]} has the least amount of cash: {i["balance"]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [160], in <cell line: 1>()
#       1 for i in data:
# ----> 2     if i['balance'].strip('$').replace(',','') == min(balance_ls):
#       3         print(f'User {i["name"]} has the least amount of cash: {i["balance"]}')
#
# NameError: name 'balance_ls' is not defined

# %%
for i in data:
    print(i["name"])
#      x=len([i]["name"])
# print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [145], in <cell line: 1>()
#       1 for i in data:
# ----> 2     print(i["name"])
#
# TypeError: string indices must be integers

# %%
print(pretty_data)
# Out:
# [
#     {
#         "_id": "54e23c3e46ab53a440b580e8",
#         "about": "Sit cillum deserunt irure laboris tempor fugiat laboris. Amet commodo amet est incididunt. Dolore qui fugiat cillum pariatur dolore excepteur elit ipsum.\r\n",
#         "address": "121 Emmons Avenue, Klondike, Kentucky, 5975",
#         "age": 39,
#         "balance": "$2,097.02",
#         "company": "ANDRYX",
#         "email": "hebertestes@andryx.com",
#         "eyeColor": "blue",
#         "favoriteFruit": "strawberry",
#         "friends": [
#             {
#                 "id": 0,
#                 "name": "Tanisha Leonard"
#             },
#             {
#                 "id": 1,
#                 "name": "Dennis Wilson"
#             },
#             {
#                 "id": 2,
#                 "name": "Lupe Howe"
#             }
#         ],
#         "gender": "male",
#         "greeting": "Hello, Hebert Estes! You have 4 unread messages.",
# ...
